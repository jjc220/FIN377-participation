# %% [markdown]
# (/inputs)
# do shape
# do balue counts
# left=stock, right=firms ,left on= ['permno', 'year'], right _on=['permno','fyear'], how='inner')

# %% [markdown]
# (
#     sample.pivot_table(index='ind',columns='state', values='permno', aggfunc=['nunique','count'])
#     .stack(level=0)
# )
#
# .style.format("{:.3f}") == this makes only 3 decimals
#
#
# always group. by firm and year

# %% [markdown]
# # Practicing on Diamonds

# %% [markdown]
# tall vs long dataset
# -do whatever is the easiet, pandas has many functions to plot by these
#
# pd.bar

# %%
import pandas as pd
import seaborn as sns
import numpy as np

diamonds = sns.load_dataset('diamonds')
diamonds # notice shape, unit, key, etc...

# my turn: lets do the usual immediate explorations including the categorical vars
diamonds.describe()
# my turn: explore carats - how many are 0.99 vs 1 carat? why?
# sns.countplot(diamonds['carat'])
# explore dist of x, y, z: what did you learn? which is width, length, depth?
print(sns.distplot(diamonds['carat'], kde=False, bins=np.arange(0.2,2.05,.05).tolist()))


# your turn: explore price - is there anything unusual? (HINT: try many bin widths)

# my turn: how is carat related to price?
# your turn: how is price related to cut?

# how should we deal with outliers? delete obs? replace with nan? winsorize? show each...
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#your turn: explore price - is there anything unusual? (HINT: try many bin widths)
sns.distplot(diamonds.query('price<2500')['price'], kde=False,bins=500)

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='kde')

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='residual')

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='reg')

# %%
sns.scatterplot(data=diamonds.query('y < 20 & x > 2.5'), x='x', y='y') #how to deal with outliers

# %%
sns.boxplot(x='carat',data=diamonds)

# %%
print(sns.violinplot(x=diamonds ['carat']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
diamonds['cut'].value_counts() #for all the categorical values
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# your turn: how is price related to cut?
sns.boxplot(data=diamonds.query('price<6000'), x='cut', y='price') #ordering matters

# %% [markdown]
# # Vis Practice

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr # you might need to install this (see above)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# don't copy and paste these lists and number in several places 
# (which is what the original "simple program" did... that's bad programming!)
# instead, create a var - if we change it here, it changes everywhere
stocks = ['AAPL','MSFT','VZ']
start_yr = 2000

# load
stock_prices = pdr.get_data_yahoo(stocks, start=start_yr)
stock_prices = stock_prices.filter(like='Adj Close') # reduce to just columns with this in the name
stock_prices.columns = stocks # put their tickers as column names
stock_prices # print
# Out:
#                   AAPL        MSFT         VZ
# Date
# 2000-01-03    3.470226   37.393559        NaN
# 2000-01-04    3.177650   36.130390        NaN
# 2000-01-05    3.224152   36.511333        NaN
# 2000-01-06    2.945139   35.288280        NaN
# 2000-01-07    3.084645   35.749432        NaN
# 2000-01-10    3.030393   36.010086        NaN
# 2000-01-11    2.875386   35.087776        NaN
# 2000-01-12    2.702940   33.944916        NaN
# 2000-01-13    2.999391   34.586529        NaN
# 2000-01-14    3.113708   36.010086        NaN
# 2000-01-18    3.222214   36.992538        NaN
# 2000-01-19    3.303592   34.325859        NaN
# 2000-01-20    3.518665   34.005070        NaN
# 2000-01-21    3.450849   33.283268        NaN
# 2000-01-24    3.293904   32.481255        NaN
# 24     AAPL 2000-02-07    3.536104
# 25     AAPL 2000-02-08    3.561293
# 26     AAPL 2000-02-09    3.491539
# 27     AAPL 2000-02-10    3.518665
# 28     AAPL 2000-02-11    3.371409
# 29     AAPL 2000-02-14    3.590356
# ...     ...        ...         ...
# 10171  MSFT 2020-03-02  172.789993
# 10172  MSFT 2020-03-03  164.509995
# 10173  MSFT 2020-03-04  170.550003
# 10174  MSFT 2020-03-05  166.270004
# 10175  MSFT 2020-03-06  161.570007
# 10176  MSFT 2020-03-09  150.619995
# 10177  MSFT 2020-03-10  160.919998
# 10178  MSFT 2020-03-11  153.630005
# 10179  MSFT 2020-03-12  139.059998
# 10180  MSFT 2020-03-13  158.830002
# 10181  MSFT 2020-03-16  135.419998
# 10182  MSFT 2020-03-17  146.570007
# 10183  MSFT 2020-03-18  140.399994
# 10184  MSFT 2020-03-19  142.710007
# 10185  MSFT 2020-03-20  137.350006
# 10186  MSFT 2020-03-23  135.979996
# 10187  MSFT 2020-03-24  148.339996
# 10188  MSFT 2020-03-25  146.919998
# 10189  MSFT 2020-03-26  156.110001
# 10190  MSFT 2020-03-27  149.699997
# 10191  MSFT 2020-03-30  160.229996
# 10192  MSFT 2020-03-31  157.710007
# 10193  MSFT 2020-04-01  152.110001
# 10194  MSFT 2020-04-02  155.259995
# 10195  MSFT 2020-04-03  153.830002
# 10196  MSFT 2020-04-06  165.270004
# 10197  MSFT 2020-04-07  163.490005
# 10198  MSFT 2020-04-08  165.130005
# 10199  MSFT 2020-04-09  165.139999
# 10200    VZ 2020-04-09   57.439999
#
# [10201 rows x 3 columns]

# %%
stock_prices['ret'] = stock_prices.groupby('Firms')['Adj Close'].pct_change()
print(stock_prices.head())
# Out:
#   Firms       Date  Adj Close       ret
# 0  AAPL 2000-01-03   3.470226       NaN
# 1  AAPL 2000-01-04   3.177650 -0.084310
# 2  AAPL 2000-01-05   3.224152  0.014634
# 3  AAPL 2000-01-06   2.945139 -0.086538
# 4  AAPL 2000-01-07   3.084645  0.047368

# %% [markdown]
# # Questions:
#
# Check that there are 3 missing observations of ret: the first return for each shouldn't exist.
#
# Describe returns for each firm separately (i.e. make one table), and your answers should match mine below.
#
# Replicate and then improve each of the three figures below.
#
# Are there any issues with this data as is? How would you fix it?

# %%
#Q1
stock_prices['ret'].isna().sum()
# Out:
# 3

# %%
#Q2
stock_prices.groupby('Firms') ['ret'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Firms
# AAPL   5099.0  0.001198  0.025678 -0.518692 -0.010383  0.000886  0.012975
# MSFT   5099.0  0.000481  0.019498 -0.155978 -0.008135  0.000332  0.008996
# VZ        0.0       NaN       NaN       NaN       NaN       NaN       NaN
#
#             max
# Firms
# AAPL   0.139049
# MSFT   0.195652
# VZ          NaN

# %%
#Q3
sns.distplot(stock_prices.query('abs(ret)<0.1')['ret'].dropna(),)  #false takes off density estimater

# %%
#Q4
sns.boxplot(x='ret',data=stock_prices.query('abs(ret)<.1')) #

# %%
sns.lineplot(data=stock_prices,x='Date', y='ret', hue='Firms')
# Out:
# /Users/julaiseicaguana/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Facet Grid
#
# 1. Define grid mXn <5
# row=gender
# col=rich/poor
# 2. .map()
# Pairplot
# -uself when
