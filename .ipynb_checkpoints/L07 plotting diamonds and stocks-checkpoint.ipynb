# %% [markdown]
# (/inputs)
# do shape
# do balue counts
# left=stock, right=firms ,left on= ['permno', 'year'], right _on=['permno','fyear'], how='inner')

# %% [markdown]
# (
#     sample.pivot_table(index='ind',columns='state', values='permno', aggfunc=['nunique','count'])
#     .stack(level=0)
# )
#
# .style.format("{:.3f}") == this makes only 3 decimals
#
#
# always group. by firm and year

# %% [markdown]
# # Practicing on Diamonds

# %% [markdown]
# tall vs long dataset
# -do whatever is the easiet, pandas has many functions to plot by these
#
# pd.bar

# %%
import pandas as pd
import seaborn as sns
import numpy as np

diamonds = sns.load_dataset('diamonds')
diamonds # notice shape, unit, key, etc...

# my turn: lets do the usual immediate explorations including the categorical vars
diamonds.describe()
# my turn: explore carats - how many are 0.99 vs 1 carat? why?
# sns.countplot(diamonds['carat'])
# explore dist of x, y, z: what did you learn? which is width, length, depth?
print(sns.distplot(diamonds['carat'], kde=False, bins=np.arange(0.2,2.05,.05).tolist()))


# your turn: explore price - is there anything unusual? (HINT: try many bin widths)

# my turn: how is carat related to price?
# your turn: how is price related to cut?

# how should we deal with outliers? delete obs? replace with nan? winsorize? show each...
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#your turn: explore price - is there anything unusual? (HINT: try many bin widths)
sns.distplot(diamonds.query('price<2500')['price'], kde=False,bins=500)

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='kde')

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='residual')

# %%
sns.jointplot(data=diamonds.query('carat<2 & price<10000'), y='price', x='carat', kind='reg')

# %%
sns.scatterplot(data=diamonds.query('y < 20 & x > 2.5'), x='x', y='y') #how to deal with outliers

# %%
sns.boxplot(x='carat',data=diamonds)

# %%
print(sns.violinplot(x=diamonds ['carat']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
diamonds['cut'].value_counts() #for all the categorical values
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# your turn: how is price related to cut?
sns.boxplot(data=diamonds.query('price<6000'), x='cut', y='price') #ordering matters

# %% [markdown]
# # Vis Practice

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr # you might need to install this (see above)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# don't copy and paste these lists and number in several places 
# (which is what the original "simple program" did... that's bad programming!)
# instead, create a var - if we change it here, it changes everywhere
stocks = ['AAPL','MSFT','VZ']
start_yr = 2000

# load
stock_prices = pdr.get_data_yahoo(stocks, start=start_yr)
stock_prices = stock_prices.filter(like='Adj Close') # reduce to just columns with this in the name
stock_prices.columns = stocks # put their tickers as column names
stock_prices # print
# Out:
#                   AAPL        MSFT         VZ
# Date
# 2000-01-03    3.470226   37.495686  20.721500
# 2000-01-04    3.177650   36.229057  20.051672
# 2000-01-05    3.224152   36.611080  20.721500
# 2000-01-06    2.945139   35.384666  20.631170
# 2000-01-07    3.084645   35.847076  20.478834
# 2000-01-10    3.030393   36.108448  20.370028
# 2000-01-11    2.875386   35.183617  20.179594
# 2000-01-12    2.702940   34.037640  19.499504
# 2000-01-13    2.999391   34.680992  19.347162
# 2000-01-14    3.113708   36.108448  19.608315
# 2000-01-18    3.222214   37.093582  20.457071
# 2000-01-19    3.303592   34.419624  20.065342
# 2000-01-20    3.518665   34.097942  20.130632
# 2000-01-21    3.450849   33.374176  20.914082
# 2000-01-24    3.293904   32.569977  20.935856
# 2000-01-25    3.479914   33.072601  20.370028
# 2000-01-26    3.415973   31.966843  20.108871
# 2000-01-27    3.410160   31.765783  20.282974
# 2000-01-28    3.150523   31.604940  20.065342
# 2000-01-31    3.216401   31.484304  21.566982
# 2000-02-01    3.107896   33.112812  20.739992
# 2000-02-02    3.063332   32.429245  20.652943
# 2000-02-03    3.202839   33.333958  20.348259
# 2000-02-04    3.348157   34.278893  20.391788
# 2000-02-07    3.536104   34.298992  20.805283
# 2000-02-08    3.561293   35.364567  20.544127
# 2000-02-09    3.491539   33.454590  20.130632
# 2000-02-10    3.518665   34.097942  19.869478
# 2000-02-11    3.371409   32.147770  19.499504
# 2000-02-14    3.590356   32.047249  19.260120
# ...                ...         ...        ...
# 2020-01-06  299.090149  159.029999  59.649231
# 2020-01-07  297.683533  157.580002  58.986130
# 2020-01-08  302.472137  160.089996  59.094997
# 2020-01-09  308.896912  162.089996  58.849998
# 2020-01-10  309.595215  161.339996  58.990002
# 2020-01-13  316.209534  163.279999  59.150002
# 2020-01-14  311.939667  162.130005  59.040001
# 2020-01-15  310.602844  163.179993  59.099998
# 2020-01-16  314.493591  166.169998  59.669998
# 2020-01-17  317.975372  167.100006  60.130001
# 2020-01-21  315.820465  166.500000  60.320000
# 2020-01-22  316.947815  165.699997  60.480000
# 2020-01-23  318.474182  166.720001  60.509998
# 2020-01-24  317.556335  165.039993  60.279999
# 2020-01-27  308.218506  162.279999  59.910000
# 2020-01-28  316.937805  165.460007  60.700001
# 2020-01-29  323.572052  168.039993  59.529999
# 2020-01-30  323.103180  172.779999  59.360001
# 2020-01-31  308.777191  170.229996  59.439999
# 2020-02-03  307.929199  174.380005  58.049999
# 2020-02-04  318.095062  180.119995  58.290001
# 2020-02-05  320.688934  179.899994  59.130001
# 2020-02-06  324.440002  183.630005  59.439999
# 2020-02-07  320.029999  183.889999  59.939999
# 2020-02-10  321.549988  188.699997  60.240002
# 2020-02-11  319.609985  184.440002  58.689999
# 2020-02-12  327.200012  184.710007  58.230000
# 2020-02-13  324.869995  183.710007  58.650002
# 2020-02-14  324.950012  185.350006  58.509998
# 2020-02-18  317.869995  186.600006  58.115002
#
# [5063 rows x 3 columns]

# %%
stock_prices=stock_prices.stack().swaplevel().sort_index().reset_index()
stock_prices.columns=['Firms', 'Date', 'Adj Close']
stock_prices#changes indexes into variables
# Out:
#       Firms       Date  Adj Close
# 0      AAPL 2000-01-03   3.470226
# 1      AAPL 2000-01-04   3.177650
# 2      AAPL 2000-01-05   3.224152
# 3      AAPL 2000-01-06   2.945139
# 4      AAPL 2000-01-07   3.084645
# 5      AAPL 2000-01-10   3.030393
# 6      AAPL 2000-01-11   2.875386
# 7      AAPL 2000-01-12   2.702940
# 8      AAPL 2000-01-13   2.999391
# 9      AAPL 2000-01-14   3.113708
# 10     AAPL 2000-01-18   3.222214
# 11     AAPL 2000-01-19   3.303592
# 12     AAPL 2000-01-20   3.518665
# 13     AAPL 2000-01-21   3.450849
# 14     AAPL 2000-01-24   3.293904
# 15     AAPL 2000-01-25   3.479914
# 16     AAPL 2000-01-26   3.415973
# 17     AAPL 2000-01-27   3.410160
# 18     AAPL 2000-01-28   3.150523
# 19     AAPL 2000-01-31   3.216401
# 20     AAPL 2000-02-01   3.107896
# 21     AAPL 2000-02-02   3.063332
# 22     AAPL 2000-02-03   3.202839
# 23     AAPL 2000-02-04   3.348157
# 24     AAPL 2000-02-07   3.536104
# 25     AAPL 2000-02-08   3.561293
# 26     AAPL 2000-02-09   3.491539
# 27     AAPL 2000-02-10   3.518665
# 28     AAPL 2000-02-11   3.371409
# 29     AAPL 2000-02-14   3.590356
# ...     ...        ...        ...
# 15159    VZ 2020-01-06  59.649231
# 15160    VZ 2020-01-07  58.986130
# 15161    VZ 2020-01-08  59.094997
# 15162    VZ 2020-01-09  58.849998
# 15163    VZ 2020-01-10  58.990002
# 15164    VZ 2020-01-13  59.150002
# 15165    VZ 2020-01-14  59.040001
# 15166    VZ 2020-01-15  59.099998
# 15167    VZ 2020-01-16  59.669998
# 15168    VZ 2020-01-17  60.130001
# 15169    VZ 2020-01-21  60.320000
# 15170    VZ 2020-01-22  60.480000
# 15171    VZ 2020-01-23  60.509998
# 15172    VZ 2020-01-24  60.279999
# 15173    VZ 2020-01-27  59.910000
# 15174    VZ 2020-01-28  60.700001
# 15175    VZ 2020-01-29  59.529999
# 15176    VZ 2020-01-30  59.360001
# 15177    VZ 2020-01-31  59.439999
# 15178    VZ 2020-02-03  58.049999
# 15179    VZ 2020-02-04  58.290001
# 15180    VZ 2020-02-05  59.130001
# 15181    VZ 2020-02-06  59.439999
# 15182    VZ 2020-02-07  59.939999
# 15183    VZ 2020-02-10  60.240002
# 15184    VZ 2020-02-11  58.689999
# 15185    VZ 2020-02-12  58.230000
# 15186    VZ 2020-02-13  58.650002
# 15187    VZ 2020-02-14  58.509998
# 15188    VZ 2020-02-18  58.115002
#
# [15189 rows x 3 columns]

# %%
stock_prices['ret'] = stock_prices.groupby('Firms')['Adj Close'].pct_change()
print(stock_prices.head())
# Out:
#   Firms       Date  Adj Close       ret
# 0  AAPL 2000-01-03   3.470226       NaN
# 1  AAPL 2000-01-04   3.177650 -0.084310
# 2  AAPL 2000-01-05   3.224152  0.014634
# 3  AAPL 2000-01-06   2.945139 -0.086538
# 4  AAPL 2000-01-07   3.084645  0.047368

# %%
#Q1
stock_prices['ret'].isna().sum()
# Out:
# 3

# %%
#Q2
stock_prices.groupby('Firms') ['ret'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Firms
# AAPL   5062.0  0.001229  0.025349 -0.518692 -0.010330  0.000895  0.012943
# MSFT   5062.0  0.000497  0.018964 -0.155977 -0.008038  0.000338  0.008928
# VZ     5062.0  0.000321  0.015347 -0.118461 -0.007231  0.000369  0.007702
#
#             max
# Firms
# AAPL   0.139049
# MSFT   0.195652
# VZ     0.146324

# %%
#question 3
sns.distplot(stock_prices.query('abs(ret)<0.1')['ret'].dropna(),)  #false takes off density estimater

# %%
sns.boxplot(x='ret',data=stock_prices.query('abs(ret)<.1')) #

# %%
sns.lineplot(data=stock_prices,x='Date', y='ret', hue='Firms')
# Out:
# /Users/julaiseicaguana/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Facet Grid
#
# 1. Define grid mXn <5
# row=gender
# col=rich/poor
# 2. .map()
# Pairplot
# -uself when
